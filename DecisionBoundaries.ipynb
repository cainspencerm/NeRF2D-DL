# %%
from nerf2d import GenerateModel
from experiments import DecisionBoundaries
from IPython.display import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
epoch_set = [0, 1, 2, 3, 10, 20, 30, 100, 200, 300, 700, 800, 900, 1000]
image = 'fractal'

rng = np.random.default_rng(12345)
neurons = rng.integers(low=0, high=128, size=3)

# %%
figs = DecisionBoundaries('saved_model', 'repeat_xy', epoch_set, neurons, image, verbose=True)
for fig in figs:
    fig.show()
# Out:
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_0
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_1
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_2
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_3
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_10
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_20
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_30
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_100
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_200
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_300
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_700
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_800
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_900
# Loaded saved_model/128x2_repeat_xy_5e-04_fractal_by-epoch/epoch_1000

# %%
figs = DecisionBoundaries('saved_model', 'sin_cos', epoch_set, neurons, image, verbose=True)
for fig in figs:
    fig.show()
# Out:
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_0
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_1
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_2
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_3
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_10
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_20
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_30
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_100
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_200
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_300
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_700
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_800
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_900
# Loaded saved_model/128x2_sin_cos_5e-04_fractal_by-epoch/epoch_1000
